# %%
from kafka import KafkaProducer
import sys, random, datetime, time, json

while True:
    if __name__ == "__main__":
        # 設定要連線到Kafka集群的相關設定, 並產生一個Kafka的Producer的實例
        producer1 = KafkaProducer(
            # 指定Kafka集群伺服器(["docker.compose.host.name:9092"])
            bootstrap_servers = ["kafka:9092"],
            # 指定msgKey的序列化器, 若Key為None, 無法序列化, 透過producer直接給值
            #key_serializer = str.encode,
            # 指定msgValue的序列化器
            #value_serializer = str.encode,
            value_serializer = lambda m: json.dumps(m).encode('ascii'),
        )

        producer2 = KafkaProducer(
            # 指定Kafka集群伺服器(["docker.compose.host.name:9092"])
            bootstrap_servers = ["kafka:9092"],
            # 指定msgKey的序列化器, 若Key為None, 無法序列化, 透過producer直接給值
            #key_serializer = str.encode,
            # 指定msgValue的序列化器
            #value_serializer = str.encode,
            value_serializer = lambda m: json.dumps(m).encode('ascii'),
        )


        try:
            device_id = "001"
            t = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            temp = round(random.uniform(18, 30), 2)
            humidity = random.randint(0, 100)
            rd = random.random()
            tt = {"device_id": device_id, "timestamp": t, "Temperature": temp, 'rd': rd}
            hh = {"device_id": device_id, "timestamp": t, "bpm": humidity, 'rd': rd}

            print("Start sending messages ...")
            # 產生要發佈到Kafka的訊息
    #         producer1.send(topic="temperature", value=tt)
    #         producer2.send(topic="humidity", value=hh)
            # producer.send(topic=topicName, key=msgKey, value=msgValue)
            future1 = producer1.send(topic="temperature", value=tt)
            record_metadata1 = future1.get(timeout=10)
            print(record_metadata1)

            future2 = producer2.send(topic="qqq", value=hh)
            record_metadata2 = future2.get(timeout=10)
            print(record_metadata2)
            print("Message sending completed!")

        except Exception as e:
            # 錯誤處理
            e_type, e_value, e_traceback = sys.exc_info()
            print("type ==> %s" % (e_type))
            print("value ==> %s" % (e_value))
            print("traceback ==> file name: %s" % (e_traceback.tb_frame.f_code.co_filename))
            print("traceback ==> line no: %s" % (e_traceback.tb_lineno))
            print("traceback ==> function name: %s" % (e_traceback.tb_frame.f_code.co_name))


        finally:
            # 關掉Producer實例的連線
            producer1.close()
            producer2.close()
#             time.sleep(2)
# Out:
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=10, timestamp=1572854272750, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='qqq', partition=0, topic_partition=TopicPartition(topic='qqq', partition=0), offset=10, timestamp=1572854272758, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=11, timestamp=1572854272984, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='qqq', partition=0, topic_partition=TopicPartition(topic='qqq', partition=0), offset=11, timestamp=1572854272992, checksum=None, serialized_key_size=-1, serialized_value_size=92, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=12, timestamp=1572854273249, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='qqq', partition=0, topic_partition=TopicPartition(topic='qqq', partition=0), offset=12, timestamp=1572854273256, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=13, timestamp=1572854273481, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='qqq', partition=0, topic_partition=TopicPartition(topic='qqq', partition=0), offset=13, timestamp=1572854273488, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=14, timestamp=1572854273713, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='qqq', partition=0, topic_partition=TopicPartition(topic='qqq', partition=0), offset=14, timestamp=1572854273720, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=15, timestamp=1572854273944, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='qqq', partition=0, topic_partition=TopicPartition(topic='qqq', partition=0), offset=15, timestamp=1572854273952, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=16, timestamp=1572854274175, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='qqq', partition=0, topic_partition=TopicPartition(topic='qqq', partition=0), offset=16, timestamp=1572854274183, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=17, timestamp=1572854274406, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='qqq', partition=0, topic_partition=TopicPartition(topic='qqq', partition=0), offset=17, timestamp=1572854274413, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=18, timestamp=1572854274636, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# RecordMetadata(topic='qqq', partition=0, topic_partition=TopicPartition(topic='qqq', partition=0), offset=18, timestamp=1572854274643, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=19, timestamp=1572854274867, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='qqq', partition=0, topic_partition=TopicPartition(topic='qqq', partition=0), offset=19, timestamp=1572854274874, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=20, timestamp=1572854275097, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='qqq', partition=0, topic_partition=TopicPartition(topic='qqq', partition=0), offset=20, timestamp=1572854275104, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=21, timestamp=1572854275331, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='qqq', partition=0, topic_partition=TopicPartition(topic='qqq', partition=0), offset=21, timestamp=1572854275337, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=22, timestamp=1572854275562, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='qqq', partition=0, topic_partition=TopicPartition(topic='qqq', partition=0), offset=22, timestamp=1572854275569, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=23, timestamp=1572854275792, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='qqq', partition=0, topic_partition=TopicPartition(topic='qqq', partition=0), offset=23, timestamp=1572854275798, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=24, timestamp=1572854276023, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='qqq', partition=0, topic_partition=TopicPartition(topic='qqq', partition=0), offset=24, timestamp=1572854276033, checksum=None, serialized_key_size=-1, serialized_value_size=93, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=25, timestamp=1572854276256, checksum=None, serialized_key_size=-1, serialized_value_size=102, serialized_header_size=-1)
# RecordMetadata(topic='qqq', partition=0, topic_partition=TopicPartition(topic='qqq', partition=0), offset=25, timestamp=1572854276265, checksum=None, serialized_key_size=-1, serialized_value_size=92, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=26, timestamp=1572854276489, checksum=None, serialized_key_size=-1, serialized_value_size=105, serialized_header_size=-1)
# RecordMetadata(topic='qqq', partition=0, topic_partition=TopicPartition(topic='qqq', partition=0), offset=26, timestamp=1572854276495, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset=27, timestamp=1572854276717, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# RecordMetadata(topic='qqq', partition=0, topic_partition=TopicPartition(topic='qqq', partition=0), offset=27, timestamp=1572854276727, checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='temperature', partition=0, topic_partition=TopicPartition(topic='temperature', partition=0), offset
checksum=None, serialized_key_size=-1, serialized_value_size=94, serialized_header_size=-1)
# Message sending completed!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-0883a757364a> in <module>
#      22             # 指定msgValue的序列化器
#      23             #value_serializer = str.encode,
# ---> 24             value_serializer = lambda m: json.dumps(m).encode('ascii'),
#      25         )
#      26
#
# ~/miniconda3/lib/python3.7/site-packages/kafka/producer/kafka.py in __init__(self, **configs)
#     379         client = KafkaClient(metrics=self._metrics, metric_group_prefix='producer',
#     380                              wakeup_timeout_ms=self.config['max_block_ms'],
# --> 381                              **self.config)
#     382
#     383         # Get auto-discovered version from client if necessary
#
# ~/miniconda3/lib/python3.7/site-packages/kafka/client_async.py in __init__(self, **configs)
#     238         if self.config['api_version'] is None:
#     239             check_timeout = self.config['api_version_auto_timeout_ms'] / 1000
# --> 240             self.config['api_version'] = self.check_version(timeout=check_timeout)
#     241
#     242     def _can_bootstrap(self):
#
# ~/miniconda3/lib/python3.7/site-packages/kafka/client_async.py in check_version(self, node_id, timeout, strict)
#     906             try:
#     907                 remaining = end - time.time()
# --> 908                 version = conn.check_version(timeout=remaining, strict=strict, topics=list(self.config['bootstrap_topics_filter']))
#     909                 if version >= (0, 10, 0):
#     910                     # cache the api versions map if it's available (starting
#
# ~/miniconda3/lib/python3.7/site-packages/kafka/conn.py in check_version(self, timeout, strict, topics)
#    1173             f = self.send(request)
#    1174             # HACK: sleeping to wait for socket to send bytes
# -> 1175             time.sleep(0.1)
#    1176             # when broker receives an unrecognized request API
#    1177             # it abruptly closes our socket.
#
# KeyboardInterrupt:

# %% [markdown]
# # 丟資料到 elasticsearch 的consumer

# %%
from kafka import KafkaProducer
import sys, random, datetime, time, json


age = ['11-20', '21-30', '31-40', '41-50']
gender = ['M', 'W']
brand = ['nike', 'adidas', 'puma', 'skecher', 'nike', 'nike', 'adidas']

while True:
    if __name__ == "__main__":
        # 設定要連線到Kafka集群的相關設定, 並產生一個Kafka的Producer的實例
        producer1 = KafkaProducer(
            # 指定Kafka集群伺服器(["docker.compose.host.name:9092"])
            bootstrap_servers = ["kafka:9092"],
            # 指定msgKey的序列化器, 若Key為None, 無法序列化, 透過producer直接給值
            #key_serializer = str.encode,
            # 指定msgValue的序列化器
            #value_serializer = str.encode,
            value_serializer = lambda m: json.dumps(m).encode('ascii'),
        )

        producer2 = KafkaProducer(
            # 指定Kafka集群伺服器(["docker.compose.host.name:9092"])
            bootstrap_servers = ["kafka:9092"],
            # 指定msgKey的序列化器, 若Key為None, 無法序列化, 透過producer直接給值
            #key_serializer = str.encode,
            # 指定msgValue的序列化器
            #value_serializer = str.encode,
            value_serializer = lambda m: json.dumps(m).encode('ascii'),
        )


        try:
            user_id = str(random.randint(1, 100))
            t = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#             temp = round(random.uniform(18, 30), 2)
#             humidity = random.randint(0, 100)
#             rd = random.random()



            hh = {"user_id": user_id, "gender": random.choice(gender), "age": random.choice(age), "timestamp": t, "brand": random.choice(brand)}

            print("Start sending messages ...")
            # 產生要發佈到Kafka的訊息


            future2 = producer2.send(topic="test2", value=hh)
            record_metadata2 = future2.get(timeout=10)
            print(record_metadata2)
            print("Message sending completed!")

        except Exception as e:
            # 錯誤處理
            e_type, e_value, e_traceback = sys.exc_info()
            print("type ==> %s" % (e_type))
            print("value ==> %s" % (e_value))
            print("traceback ==> file name: %s" % (e_traceback.tb_frame.f_code.co_filename))
            print("traceback ==> line no: %s" % (e_traceback.tb_lineno))
            print("traceback ==> function name: %s" % (e_traceback.tb_frame.f_code.co_name))


        finally:
            # 關掉Producer實例的連線
#             producer1.close()
            producer2.close()
#             time.sleep(2)
# Out:
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=
serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9187, timestamp=1572876347183, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9188, timestamp=1572876347404, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9189, timestamp=1572876347625, checksum=None, serialized_key_size=-1, serialized_value_size=101, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9190, timestamp=1572876347846, checksum=None, serialized_key_size=-1, serialized_value_size=101, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9191, timestamp=1572876348067, checksum=None, serialized_key_size=-1, serialized_value_size=101, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9192, timestamp=1572876348288, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9193, timestamp=1572876348509, checksum=None, serialized_key_size=-1, serialized_value_size=102, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9194, timestamp=1572876348731, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9195, timestamp=1572876348951, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9196, timestamp=1572876349172, checksum=None, serialized_key_size=-1, serialized_value_size=101, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9197, timestamp=1572876349392, checksum=None, serialized_key_size=-1, serialized_value_size=101, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9198, timestamp=1572876349615, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9199, timestamp=1572876349835, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9200, timestamp=1572876350057, checksum=None, serialized_key_size=-1, serialized_value_size=101, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9201, timestamp=1572876350279, checksum=None, serialized_key_size=-1, serialized_value_size=101, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9202, timestamp=1572876350533, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9203, timestamp=1572876350754, checksum=None, serialized_key_size=-1, serialized_value_size=101, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9204, timestamp=1572876350974, checksum=None, serialized_key_size=-1, serialized_value_size=100, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9205, timestamp=1572876351196, checksum=None, serialized_key_size=-1, serialized_value_size=101, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9206, timestamp=1572876351416, checksum=None, serialized_key_size=-1, serialized_value_size=104, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9207, timestamp=1572876351636, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9208, timestamp=1572876351856, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9209, timestamp=1572876352083, checksum=None, serialized_key_size=-1, serialized_value_size=101, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9210, timestamp=1572876352305, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9211, timestamp=1572876352526, checksum=None, serialized_key_size=-1, serialized_value_size=101, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9212, timestamp=1572876352749, checksum=None, serialized_key_size=-1, serialized_value_size=101, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9213, timestamp=1572876352970, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9214, timestamp=1572876353194, checksum=None, serialized_key_size=-1, serialized_value_size=101, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9215, timestamp=1572876353414, checksum=None, serialized_key_size=-1, serialized_value_size=101, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9216, timestamp=1572876353636, checksum=None, serialized_key_size=-1, serialized_value_size=101, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9217, timestamp=1572876353857, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9218, timestamp=1572876354078, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9219, timestamp=1572876354300, checksum=None, serialized_key_size=-1, serialized_value_size=102, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9220, timestamp=1572876354521, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9221, timestamp=1572876354777, checksum=None, serialized_key_size=-1, serialized_value_size=101, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9222, timestamp=1572876354997, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9223, timestamp=1572876355219, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9224, timestamp=1572876355439, checksum=None, serialized_key_size=-1, serialized_value_size=101, serialized_header_size=-1)
# Message sending completed!
# Start sending messages ...
# RecordMetadata(topic='test2', partition=0, topic_partition=TopicPartition(topic='test2', partition=0), offset=9225, timestamp=1572876355661, checksum=None, serialized_key_size=-1, serialized_value_size=103, serialized_header_size=-1)
# Message sending completed!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-07a1dac84fe4> in <module>
#      17             # 指定msgValue的序列化器
#      18             #value_serializer = str.encode,
# ---> 19             value_serializer = lambda m: json.dumps(m).encode('ascii'),
#      20         )
#      21
#
# ~/miniconda3/lib/python3.7/site-packages/kafka/producer/kafka.py in __init__(self, **configs)
#     379         client = KafkaClient(metrics=self._metrics, metric_group_prefix='producer',
#     380                              wakeup_timeout_ms=self.config['max_block_ms'],
# --> 381                              **self.config)
#     382
#     383         # Get auto-discovered version from client if necessary
#
# ~/miniconda3/lib/python3.7/site-packages/kafka/client_async.py in __init__(self, **configs)
#     238         if self.config['api_version'] is None:
#     239             check_timeout = self.config['api_version_auto_timeout_ms'] / 1000
# --> 240             self.config['api_version'] = self.check_version(timeout=check_timeout)
#     241
#     242     def _can_bootstrap(self):
#
# ~/miniconda3/lib/python3.7/site-packages/kafka/client_async.py in check_version(self, node_id, timeout, strict)
#     906             try:
#     907                 remaining = end - time.time()
# --> 908                 version = conn.check_version(timeout=remaining, strict=strict, topics=list(self.config['bootstrap_topics_filter']))
#     909                 if version >= (0, 10, 0):
#     910                     # cache the api versions map if it's available (starting
#
# ~/miniconda3/lib/python3.7/site-packages/kafka/conn.py in check_version(self, timeout, strict, topics)
#    1173             f = self.send(request)
#    1174             # HACK: sleeping to wait for socket to send bytes
# -> 1175             time.sleep(0.1)
#    1176             # when broker receives an unrecognized request API
#    1177             # it abruptly closes our socket.
#
# KeyboardInterrupt:

# %%
age = ['11-20', '21-30', '31-40', '41-50']
gender = ['M', 'W']
brand = ['nike', 'adidas', 'puma', 'skecher']


for i in range(1000):
    doc = {
        'user_id': str(i),
        random.choice(gender): 1,
        random.choice(age): 1,
        random.choice(brand): 1,
        'timestamp': datetime.now()
    }
