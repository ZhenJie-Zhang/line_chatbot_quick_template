# %%
import mysql.connector
import json

secretFileContentJson=json.load(open("./line_secret_key",'r'))
server_url=secretFileContentJson.get("server_url")

cursor = None
conn = None
l = 'white'
try:
    # 建立連線 並指定 database
    conn = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db', database='TEST1')
    cursor = conn.cursor()
    
    # 下 query指令 範例：只找 mcolor_label = 2 的資料
    query = "SELECT pid, pro_name, brand FROM shoes_data WHERE coler_label = "+repr(l)+" && mcolor_name like '%"+l+"%' ORDER BY RAND(), mcolor_pa desc LIMIT 5"
    print(query)
    cursor.execute(query)
    
    # 顯示讀取到的資料
#     for pid, mcolor_label, scolor_label, mcolor_id in cursor:
#         print('pid={}, m_label={}, s_label={}, mc_id={}'.format(pid, mcolor_label, scolor_label, mcolor_id))
    col_list = []
    for pid, pro_name, brand in cursor:
        pic_url = 'https://'+server_url+'/material/product/'+pid+'.jpg'
        print(pid, pro_name, brand, pic_url)
        #循環加到 list_col_color
        col = {
                "thumbnailImageUrl": pic_url,
                "title": pro_name,
                "text": "所顏是否?",
                "actions": [
                  {
                    "type": "postback",
                    "label": "喜歡",
                    "text": "加入喜好清單",
                    "data": "tag=maincolor|Secondarycolor|"+pid
                  },
                  {
                    "type": "postback",
                    "label": "不喜歡",
                    "text": "不喜歡"+pro_name,
                    "data": "tag=maincolor|Secondarycolor|"+pid
                  }
                ]
              }
        col_list.append(col)

    #輸出到linebot輪播
    data = [
        {
            "type": "template",
            "altText": "情境輸入推薦清單",
            "template":{
                    "type": "carousel",
                    "actions": [],
                    "columns": col_list
            }
        }
    ]
    print(json.dumps(data, indent=2,ensure_ascii=False))


    print('total', cursor.rowcount, 'shoes_data')
# 關閉連線
finally:
    cursor.close()
# Out:
# SELECT pid, pro_name, brand FROM shoes_data WHERE coler_label = 'white' && mcolor_name like '%white%' ORDER BY RAND(), mcolor_pa desc LIMIT 5
# EE5789 adidas Stan Smith Shoes - White | adidas US adidas https://sneakerdb103g3.serveo.net/material/product/EE5789.jpg
# 68677_WHT Men's Shogun - Mondo skechers https://sneakerdb103g3.serveo.net/material/product/68677_WHT.jpg
# EF3454 adidas Alphaedge 4D Shoes - White | adidas US adidas https://sneakerdb103g3.serveo.net/material/product/EF3454.jpg
# 54535_WBK Men's Skechers GO GOLF Pro V.4 skechers https://sneakerdb103g3.serveo.net/material/product/54535_WBK.jpg
# EE5118 adidas Falcon Shoes - White | adidas US adidas https://sneakerdb103g3.serveo.net/material/product/EE5118.jpg
# [
#   {
#     "type": "template",
#     "altText": "情境輸入推薦清單",
#     "template": {
#       "type": "carousel",
#       "actions": [],
#       "columns": [
#         {
#           "thumbnailImageUrl": "https://sneakerdb103g3.serveo.net/material/product/EE5789.jpg",
#           "title": "adidas Stan Smith Shoes - White | adidas US",
#           "text": "所顏是否?",
#           "actions": [
#             {
#               "type": "postback",
#               "label": "喜歡",
#               "text": "加入喜好清單",
#               "data": "tag=maincolor|Secondarycolor|EE5789"
#             },
#             {
#               "type": "postback",
#               "label": "不喜歡",
#               "text": "不喜歡adidas Stan Smith Shoes - White | adidas US",
#               "data": "tag=maincolor|Secondarycolor|EE5789"
#             }
#           ]
#         },
#         {
#           "thumbnailImageUrl": "https://sneakerdb103g3.serveo.net/material/product/68677_WHT.jpg",
#           "title": "Men's Shogun - Mondo",
#           "text": "所顏是否?",
#           "actions": [
#             {
#               "type": "postback",
#               "label": "喜歡",
#               "text": "加入喜好清單",
#               "data": "tag=maincolor|Secondarycolor|68677_WHT"
#             },
#             {
#               "type": "postback",
#               "label": "不喜歡",
#               "text": "不喜歡Men's Shogun - Mondo",
#               "data": "tag=maincolor|Secondarycolor|68677_WHT"
#             }
#           ]
#         },
#         {
#           "thumbnailImageUrl": "https://sneakerdb103g3.serveo.net/material/product/EF3454.jpg",
#           "title": "adidas Alphaedge 4D Shoes - White | adidas US",
#           "text": "所顏是否?",
#           "actions": [
#             {
#               "type": "postback",
#               "label": "喜歡",
#               "text": "加入喜好清單",
#               "data": "tag=maincolor|Secondarycolor|EF3454"
#             },
#             {
#               "type": "postback",
#               "label": "不喜歡",
#               "text": "不喜歡adidas Alphaedge 4D Shoes - White | adidas US",
#               "data": "tag=maincolor|Secondarycolor|EF3454"
#             }
#           ]
#         },
#         {
#           "thumbnailImageUrl": "https://sneakerdb103g3.serveo.net/material/product/54535_WBK.jpg",
#           "title": "Men's Skechers GO GOLF Pro V.4",
#           "text": "所顏是否?",
#           "actions": [
#             {
#               "type": "postback",
#               "label": "喜歡",
#               "text": "加入喜好清單",
#               "data": "tag=maincolor|Secondarycolor|54535_WBK"
#             },
#             {
#               "type": "postback",
#               "label": "不喜歡",
#               "text": "不喜歡Men's Skechers GO GOLF Pro V.4",
#               "data": "tag=maincolor|Secondarycolor|54535_WBK"
#             }
#           ]
#         },
#         {
#           "thumbnailImageUrl": "https://sneakerdb103g3.serveo.net/material/product/EE5118.jpg",
#           "title": "adidas Falcon Shoes - White | adidas US",
#           "text": "所顏是否?",
#           "actions": [
#             {
#               "type": "postback",
#               "label": "喜歡",
#               "text": "加入喜好清單",
#               "data": "tag=maincolor|Secondarycolor|EE5118"
#             },
#             {
#               "type": "postback",
#               "label": "不喜歡",
#               "text": "不喜歡adidas Falcon Shoes - White | adidas US",
#               "data": "tag=maincolor|Secondarycolor|EE5118"
#             }
#           ]
#         }
#       ]
#     }
#   }
# ]
# total 5 shoes_data

# %%
import mysql.connector
import json

userid = '999'

try:
    # 建立連線 並指定 database
    conn = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db', database='TEST1')
    cursor = conn.cursor()
    
    # 下 query指令 範例：只找 mcolor_label = 2 的資料
    query = "SELECT pid, pro_name, brand FROM shoes_data WHERE coler_label = "+repr(l)+" && mcolor_name like '%"+l+"%' ORDER BY RAND(), mcolor_pa desc LIMIT 5"
    print(query)
    cursor.execute(query)
    
    # 顯示讀取到的資料
#     for pid, mcolor_label, scolor_label, mcolor_id in cursor:
#         print('pid={}, m_label={}, s_label={}, mc_id={}'.format(pid, mcolor_label, scolor_label, mcolor_id))
    contentsList = []
    for pid, pro_name, brand in cursor:
        pic_url = 'https://'+server_url+'/material/product/'+pid+'.jpg'
        print(pid, pro_name, brand, pic_url)
        #循環加到 list_col_color

        bubbleDict = {
                "type": "bubble",
                "direction": "ltr",
                "hero": {
                  "type": "image",
                  "url": pic_url,
                  "size": "full",
                  "aspectRatio": "1.51:1",
                  "aspectMode": "fit"
                },
                "body": {
                  "type": "box",
                  "layout": "vertical",
                  "contents": [
                    {
                      "type": "text",
                      "text": pro_name[:40],
                      "align": "center"
                    },
                    {
                      "type": "box",
                      "layout": "horizontal",
                      "contents": [
                        {
                          "type": "button",
                          "action": {
                            "type": "postback",
                            "label": "加入購物車",
                            "text": "我要"+pro_name[:10],
                            "data": "product="+pid+"&user="+userid
                          }
                        },
                        {
                          "type": "button",
                          "action": {
                            "type": "postback",
                            "label": "加入收藏",
                            "data": "product="+pid+"&user="+userid
                          }
                        }
                      ]
                    },
                    {
                      "type": "separator"
                    }
                  ]
                },
                "footer": {
                  "type": "box",
                  "layout": "horizontal",
                  "contents": [
                    {
                      "type": "text",
                      "text": "喜好",
                      "gravity": "center"
                    },
                    {
                      "type": "button",
                      "action": {
                        "type": "postback",
                        "label": "1",
                        "data": "rating=1&product="+pid+"&user="+userid
                      }
                    },
                    {
                      "type": "button",
                      "action": {
                        "type": "postback",
                        "label": "2",
                        "data": "rating=2&product="+pid+"&user="+userid
                      }
                    },
                    {
                      "type": "button",
                      "action": {
                        "type": "postback",
                        "label": "3",
                        "data": "rating=3&product="+pid+"&user="+userid
                      }
                    },
                    {
                      "type": "button",
                      "action": {
                        "type": "postback",
                        "label": "4",
                        "data": "rating=4&product="+pid+"&user="+userid
                      }
                    },
                    {
                      "type": "button",
                      "action": {
                        "type": "postback",
                        "label": "5",
                        "data": "rating=5&product="+pid+"&user="+userid
                      }
                    }
                  ]
                }
              }

        contentsList.append(bubbleDict)
    Flex_Message = [{
      "type": "flex",
      "altText": "Flex Message",
      "contents": {
        "type": "carousel",
        "contents": contentsList
      }
    }]
# 關閉連線
finally:
    cursor.close()
    print(json.dumps(Flex_Message, indent=2,ensure_ascii=False))
# Out:
# SELECT pid, pro_name, brand FROM shoes_data WHERE coler_label = 'white' && mcolor_name like '%white%' ORDER BY RAND(), mcolor_pa desc LIMIT 5
# EE8498 adidas Originals by AW B-Ball Soccer Shoes - White | adidas US adidas https://sneakerdb103g3.serveo.net/material/product/EE8498.jpg
# 68671_WHT Men's Shogun - Down Time skechers https://sneakerdb103g3.serveo.net/material/product/68671_WHT.jpg
# AQ1189-190 Nike Metcon 5 nike https://sneakerdb103g3.serveo.net/material/product/AQ1189-190.jpg
# EE4723 adidas Sleek Shoes - Beige | adidas US adidas https://sneakerdb103g3.serveo.net/material/product/EE4723.jpg
# SMFUSEW2 Fuse v2 Low Cut Metal new balance https://sneakerdb103g3.serveo.net/material/product/SMFUSEW2.jpg
# [
#   {
#     "type": "flex",
#     "altText": "Flex Message",
#     "contents": {
#       "type": "carousel",
#       "contents": [
#         {
#           "type": "bubble",
#           "direction": "ltr",
#           "hero": {
#             "type": "image",
#             "url": "https://sneakerdb103g3.serveo.net/material/product/EE8498.jpg",
#             "size": "full",
#             "aspectRatio": "1.51:1",
#             "aspectMode": "fit"
#           },
#           "body": {
#             "type": "box",
#             "layout": "vertical",
#             "contents": [
#               {
#                 "type": "text",
#                 "text": "adidas Originals by AW B-Ball Soccer Sho",
#                 "align": "center"
#               },
#               {
#                 "type": "box",
#                 "layout": "horizontal",
#                 "contents": [
#                   {
#                     "type": "button",
#                     "action": {
#                       "type": "postback",
#                       "label": "加入購物車",
#                       "text": "我要adidas Ori",
#                       "data": "product=EE8498&user=999"
#                     }
#                   },
#                   {
#                     "type": "button",
#                     "action": {
#                       "type": "postback",
#                       "label": "加入收藏",
#                       "data": "product=EE8498&user=999"
#                     }
#                   }
#                 ]
#               },
#               {
#                 "type": "separator"
#               }
#             ]
#           },
#           "footer": {
#             "type": "box",
#             "layout": "horizontal",
#             "contents": [
#               {
#                 "type": "text",
#                 "text": "喜好",
#                 "gravity": "center"
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "1",
#                   "data": "rating=1&product=EE8498&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "2",
#                   "data": "rating=2&product=EE8498&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "3",
#                   "data": "rating=3&product=EE8498&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "4",
#                   "data": "rating=4&product=EE8498&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "5",
#                   "data": "rating=5&product=EE8498&user=999"
#                 }
#               }
#             ]
#           }
#         },
#         {
#           "type": "bubble",
#           "direction": "ltr",
#           "hero": {
#             "type": "image",
#             "url": "https://sneakerdb103g3.serveo.net/material/product/68671_WHT.jpg",
#             "size": "full",
#             "aspectRatio": "1.51:1",
#             "aspectMode": "fit"
#           },
#           "body": {
#             "type": "box",
#             "layout": "vertical",
#             "contents": [
#               {
#                 "type": "text",
#                 "text": "Men's Shogun - Down Time",
#                 "align": "center"
#               },
#               {
#                 "type": "box",
#                 "layout": "horizontal",
#                 "contents": [
#                   {
#                     "type": "button",
#                     "action": {
#                       "type": "postback",
#                       "label": "加入購物車",
#                       "text": "我要Men's Shog",
#                       "data": "product=68671_WHT&user=999"
#                     }
#                   },
#                   {
#                     "type": "button",
#                     "action": {
#                       "type": "postback",
#                       "label": "加入收藏",
#                       "data": "product=68671_WHT&user=999"
#                     }
#                   }
#                 ]
#               },
#               {
#                 "type": "separator"
#               }
#             ]
#           },
#           "footer": {
#             "type": "box",
#             "layout": "horizontal",
#             "contents": [
#               {
#                 "type": "text",
#                 "text": "喜好",
#                 "gravity": "center"
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "1",
#                   "data": "rating=1&product=68671_WHT&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "2",
#                   "data": "rating=2&product=68671_WHT&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "3",
#                   "data": "rating=3&product=68671_WHT&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "4",
#                   "data": "rating=4&product=68671_WHT&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "5",
#                   "data": "rating=5&product=68671_WHT&user=999"
#                 }
#               }
#             ]
#           }
#         },
#         {
#           "type": "bubble",
#           "direction": "ltr",
#           "hero": {
#             "type": "image",
#             "url": "https://sneakerdb103g3.serveo.net/material/product/AQ1189-190.jpg",
#             "size": "full",
#             "aspectRatio": "1.51:1",
#             "aspectMode": "fit"
#           },
#           "body": {
#             "type": "box",
#             "layout": "vertical",
#             "contents": [
#               {
#                 "type": "text",
#                 "text": "Nike Metcon 5",
#                 "align": "center"
#               },
#               {
#                 "type": "box",
#                 "layout": "horizontal",
#                 "contents": [
#                   {
#                     "type": "button",
#                     "action": {
#                       "type": "postback",
#                       "label": "加入購物車",
#                       "text": "我要Nike Metco",
#                       "data": "product=AQ1189-190&user=999"
#                     }
#                   },
#                   {
#                     "type": "button",
#                     "action": {
#                       "type": "postback",
#                       "label": "加入收藏",
#                       "data": "product=AQ1189-190&user=999"
#                     }
#                   }
#                 ]
#               },
#               {
#                 "type": "separator"
#               }
#             ]
#           },
#           "footer": {
#             "type": "box",
#             "layout": "horizontal",
#             "contents": [
#               {
#                 "type": "text",
#                 "text": "喜好",
#                 "gravity": "center"
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "1",
#                   "data": "rating=1&product=AQ1189-190&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "2",
#                   "data": "rating=2&product=AQ1189-190&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "3",
#                   "data": "rating=3&product=AQ1189-190&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "4",
#                   "data": "rating=4&product=AQ1189-190&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "5",
#                   "data": "rating=5&product=AQ1189-190&user=999"
#                 }
#               }
#             ]
#           }
#         },
#         {
#           "type": "bubble",
#           "direction": "ltr",
#           "hero": {
#             "type": "image",
#             "url": "https://sneakerdb103g3.serveo.net/material/product/EE4723.jpg",
#             "size": "full",
#             "aspectRatio": "1.51:1",
#             "aspectMode": "fit"
#           },
#           "body": {
#             "type": "box",
#             "layout": "vertical",
#             "contents": [
#               {
#                 "type": "text",
#                 "text": "adidas Sleek Shoes - Beige | adidas US",
#                 "align": "center"
#               },
#               {
#                 "type": "box",
#                 "layout": "horizontal",
#                 "contents": [
#                   {
#                     "type": "button",
#                     "action": {
#                       "type": "postback",
#                       "label": "加入購物車",
#                       "text": "我要adidas Sle",
#                       "data": "product=EE4723&user=999"
#                     }
#                   },
#                   {
#                     "type": "button",
#                     "action": {
#                       "type": "postback",
#                       "label": "加入收藏",
#                       "data": "product=EE4723&user=999"
#                     }
#                   }
#                 ]
#               },
#               {
#                 "type": "separator"
#               }
#             ]
#           },
#           "footer": {
#             "type": "box",
#             "layout": "horizontal",
#             "contents": [
#               {
#                 "type": "text",
#                 "text": "喜好",
#                 "gravity": "center"
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "1",
#                   "data": "rating=1&product=EE4723&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "2",
#                   "data": "rating=2&product=EE4723&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "3",
#                   "data": "rating=3&product=EE4723&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "4",
#                   "data": "rating=4&product=EE4723&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "5",
#                   "data": "rating=5&product=EE4723&user=999"
#                 }
#               }
#             ]
#           }
#         },
#         {
#           "type": "bubble",
#           "direction": "ltr",
#           "hero": {
#             "type": "image",
#             "url": "https://sneakerdb103g3.serveo.net/material/product/SMFUSEW2.jpg",
#             "size": "full",
#             "aspectRatio": "1.51:1",
#             "aspectMode": "fit"
#           },
#           "body": {
#             "type": "box",
#             "layout": "vertical",
#             "contents": [
#               {
#                 "type": "text",
#                 "text": "Fuse v2 Low Cut Metal",
#                 "align": "center"
#               },
#               {
#                 "type": "box",
#                 "layout": "horizontal",
#                 "contents": [
#                   {
#                     "type": "button",
#                     "action": {
#                       "type": "postback",
#                       "label": "加入購物車",
#                       "text": "我要Fuse v2 Lo",
#                       "data": "product=SMFUSEW2&user=999"
#                     }
#                   },
#                   {
#                     "type": "button",
#                     "action": {
#                       "type": "postback",
#                       "label": "加入收藏",
#                       "data": "product=SMFUSEW2&user=999"
#                     }
#                   }
#                 ]
#               },
#               {
#                 "type": "separator"
#               }
#             ]
#           },
#           "footer": {
#             "type": "box",
#             "layout": "horizontal",
#             "contents": [
#               {
#                 "type": "text",
#                 "text": "喜好",
#                 "gravity": "center"
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "1",
#                   "data": "rating=1&product=SMFUSEW2&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "2",
#                   "data": "rating=2&product=SMFUSEW2&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "3",
#                   "data": "rating=3&product=SMFUSEW2&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "4",
#                   "data": "rating=4&product=SMFUSEW2&user=999"
#                 }
#               },
#               {
#                 "type": "button",
#                 "action": {
#                   "type": "postback",
#                   "label": "5",
#                   "data": "rating=5&product=SMFUSEW2&user=999"
#                 }
#               }
#             ]
#           }
#         }
#       ]
#     }
#   }
# ]

# %% [markdown]
# # 建立shoes_rating表格至MySQL

# %%
import mysql.connector

db = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db')

cursor = db.cursor()

# 新建 database
cursor.execute("DROP DATABASE IF EXISTS user")
cursor.execute("CREATE DATABASE IF not EXISTS user")

# 顯示目前所有的database
cursor.execute("SHOW DATABASES")

for x in cursor:
    print(x)
# Out:
# ('TEST1',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('user',)

# %%
import pandas as pd
from sqlalchemy import create_engine
df1 = pd.read_csv('/root/linechatbot/recommend/ratings.csv', encoding='utf-8')

#csv 匯入 DB
engine = create_engine('mysql+pymysql://root:123456@chatbot_db/user?charset=utf8')

with engine.connect() as conn, conn.begin():
    df1.to_sql('shoes_rating', conn, if_exists='replace', index=True)

df1

#build connenction
import pymysql
connection = pymysql.connect(host='chatbot_db', 
                             user='root',
                             password='123456',
                             charset='utf8mb4',
                             database='TEST1',
                             cursorclass=pymysql.cursors.DictCursor)

with connection.cursor() as cursor:
    sql = "USE `user`"
    cursor.execute(sql)
    sql_query = "SELECT * FROM `shoes_rating`"
    cursor.execute(sql_query)
    result = cursor.fetchone()
    print(result)

# %%
import mysql.connector

cursor = None
conn = None
try:
    # 建立連線 並指定 database
    conn = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db', database='user')
    cursor = conn.cursor()
    
    # 下 query指令 範例：只找 mcolor_label = 2 的資料
    query = "SELECT count(*) FROM `shoes_rating`"
#     query = "SELECT pid, mcolor_label, scolor_label FROM shoes_data"
#     query = "SELECT * FROM shoes_data"
    cursor.execute(query)
    
    # 顯示讀取到的資料
#     for pid, mcolor_label, scolor_label, mcolor_id in cursor:
#         print('pid={}, m_label={}, s_label={}, mc_id={}'.format(pid, mcolor_label, scolor_label, mcolor_id))
    for c in cursor:
        print(c)
        
    print('total', cursor.rowcount, 'shoes_data')
# 關閉連線
finally:
    cursor.close()
# Out:
# (77939,)
# total 1 shoes_data

# %% [markdown]
# # 建立shoes表格至MySQL

# %%
import mysql.connector

db = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db')

cursor = db.cursor()

# 新建 database
# cursor.execute("DROP DATABASE IF EXISTS user")
# cursor.execute("CREATE DATABASE IF not EXISTS user")

# 顯示目前所有的database
cursor.execute("SHOW DATABASES")

for x in cursor:
    print(x)
# Out:
# ('TEST1',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('user',)

# %%
import pandas as pd
from sqlalchemy import create_engine
df1 = pd.read_csv('/root/linechatbot/recommend/shoes.csv', encoding='cp950')

#csv 匯入 DB
engine = create_engine('mysql+pymysql://root:123456@chatbot_db/user?charset=utf8')

with engine.connect() as conn, conn.begin():
    df1.to_sql('shoes', conn, if_exists='replace', index=True)

df1

# %%
#build connenction
import pymysql
connection = pymysql.connect(host='chatbot_db', 
                             user='root',
                             password='123456',
                             charset='utf8mb4',
                             database='TEST1',
                             cursorclass=pymysql.cursors.DictCursor)

with connection.cursor() as cursor:
    sql = "USE `user`"
    cursor.execute(sql)
    sql_query = "SELECT * FROM `shoes`"
    cursor.execute(sql_query)
    result = cursor.fetchone()
    print(result)
# Out:
# {'index': 0, 'shoesIDX': 1, 'shoesID': '11040', 'pro_name': 'adidas World Cup Cleats - Black | adidas US'}

# %%
import mysql.connector

cursor = None
conn = None
try:
    # 建立連線 並指定 database
    conn = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db', database='user')
    cursor = conn.cursor()
    
    # 下 query指令 範例：只找 mcolor_label = 2 的資料
    query = "SELECT shoesIDX, shoesID FROM `shoes` where shoesID = 'WZANSCS'"
    cursor.execute(query)
    
    # 顯示讀取到的資料
    for shoesIDX,shoesID in cursor:
        print(shoesIDX,shoesID)
#     for c in cursor:
#         print(c[0])
        
    print('total', cursor.rowcount, 'shoes')
# 關閉連線
finally:
    cursor.close()
# Out:
# 9693 WZANSCS
# total 1 shoes

# %%
#Creating, Reading, Updating and Deleting Records
import redis
import mysql.connector

conn3 = redis.StrictRedis(
    host='redis',
    port="6379",
    password='123456',
    ssl=False, charset="utf-8", decode_responses=True)
shoes_list = eval(conn3.hget("shoes", 167))
for i, s in enumerate(shoes_list):
#     print(i+1, s)
    
    cursor = None
    conn = None
    try:
        # 建立連線 並指定 database
        conn = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db', database='user')
        cursor = conn.cursor()

        # 下 query指令 範例：只找 mcolor_label = 2 的資料
        query = "SELECT shoesIDX, shoesID FROM `shoes` where shoesID = "+repr(s[0])
        cursor.execute(query)

        # 顯示讀取到的資料
        for shoesIDX,shoesID in cursor:
            print(shoesIDX,shoesID)

    # 關閉連線
    finally:
        cursor.close()
        print("-----")
# Out:
# 2959 49662_BBK
# -----
# 1223 12646_NVHP
# -----
# 296 1012A117-002
# -----
# 5618 B79759
# -----
# 1136 1193A042-400
# -----
# 7361 EE7064
# -----
# 1235 12753_BKLB
# -----
# 858 1081A021-600
# -----
# 318 1012A146-002
# -----
# 745 1.04E+16
# 746 1.04E+16
# 747 1.04E+16
# 748 1.04E+16
# 749 1.04E+16
# 750 1.04E+16
# 751 1.04E+16
# 752 1.04E+16
# 753 1.04E+16
# 754 1.04E+16
# -----
# 741 1032A004-400
# -----
# 1089 1192A125-001
# -----
# 50 1011A131-031
# -----
# 3681 66384_BRN
# -----
# 6874 DB0570
# -----
# 1203 12119_BBK
# -----
# 8874 MMORLB
# -----
# 1080 1192A114-200
# -----
# 1197 1193A162-101
# -----
# 1199 11940_NVW
# -----
# 3275 54523_WNV
# -----
# 1250 12841_BBK
# -----
# 4226 AA0286-100
# -----
# 1206 124002_BKW
# -----
# 7153 EE5540
# -----

# %%
import mysql.connector
import json

secretFileContentJson=json.load(open("./line_secret_key",'r'))
server_url=secretFileContentJson.get("server_url")

userid = '999'

try:
    # 建立連線 並指定 database
    conn = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db', database='TEST1')
    cursor = conn.cursor()
    
    # 下 query指令 範例：只找 mcolor_label = 2 的資料
    query = "SELECT pid, pro_name, brand FROM shoes_data ORDER BY RAND() LIMIT 1"
    print(query)
    cursor.execute(query)
    
    # 顯示讀取到的資料
#     for pid, mcolor_label, scolor_label, mcolor_id in cursor:
#         print('pid={}, m_label={}, s_label={}, mc_id={}'.format(pid, mcolor_label, scolor_label, mcolor_id))
    contentsList = []
    for pid, pro_name, brand in cursor:
        pic_url = 'https://'+server_url+'/material/product/'+pid+'.jpg'
        print(pid, pro_name, brand, pic_url)
        #循環加到 list_col_color
        flextemplate = {
                      "type": "flex",
                      "altText": "Flex Message",
                      "contents": {
                        "type": "bubble",
                        "direction": "ltr",
                        "hero": {
                          "type": "image",
                          "url": pic_url,
                          "size": "full",
                          "aspectRatio": "1.51:1",
                          "aspectMode": "fit"
                        },
                        "body": {
                          "type": "box",
                          "layout": "vertical",
                          "contents": [
                            {
                              "type": "text",
                              "text": brand,
                              "align": "center",
                              "weight": "bold"
                            },
                            {
                              "type": "text",
                              "text": pro_name,
                              "align": "center"
                            },
                            {
                              "type": "box",
                              "layout": "horizontal",
                              "contents": [
                                {
                                  "type": "button",
                                  "action": {
                                    "type": "postback",
                                    "label": "加入購物車",
                                    "text": "::我要:"+pro_name[:10],
                                    "data": "tag=cart&product="+pid+"&userid="+userid
                                  }
                                },
                                {
                                  "type": "button",
                                  "action": {
                                    "type": "postback",
                                    "label": "加入收藏",
                                    "text": pro_name[:10]+"::加入收藏:",
                                    "data": "tag=collection&product="+pid+"&userid="+userid
                                  }
                                }
                              ]
                            },
                            {
                              "type": "separator"
                            }
                          ]
                        },
                        "footer": {
                          "type": "box",
                          "layout": "horizontal",
                          "contents": [
                            {
                              "type": "text",
                              "text": "評分",
                              "gravity": "center"
                            },
                            {
                              "type": "button",
                              "action": {
                                "type": "postback",
                                "label": "1",
                                "data": "tag=Productsrecommend&rating=1&product="+pid+"&userid="+userid
                              }
                            },
                            {
                              "type": "button",
                              "action": {
                                "type": "postback",
                                "label": "2",
                                "data": "tag=Productsrecommend&rating=2&product="+pid+"&userid="+userid
                              }
                            },
                            {
                              "type": "button",
                              "action": {
                                "type": "postback",
                                "label": "3",
                                "data": "tag=Productsrecommend&rating=3&product="+pid+"&userid="+userid
                              }
                            },
                            {
                              "type": "button",
                              "action": {
                                "type": "postback",
                                "label": "4",
                                "data": "tag=Productsrecommend&rating=4&product="+pid+"&userid="+userid
                              }
                            },
                            {
                              "type": "button",
                              "action": {
                                "type": "postback",
                                "label": "5",
                                "data": "tag=Productsrecommend&rating=5&product="+pid+"&userid="+userid
                              }
                            }
                          ]
                        }
                      }
                    }
    print(flextemplate)
            
# 關閉連線
finally:
    cursor.close()
#     print(json.dumps(Flex_Message, indent=2,ensure_ascii=False))
# Out:
# SELECT pid, pro_name, brand FROM shoes_data ORDER BY RAND() LIMIT 1
# 33399_CSNT Women's BOBS Beach Bingo 2 skechers https://sneakerdb103g3.serveo.net/material/product/33399_CSNT.jpg
# {'type': 'flex', 'altText': 'Flex Message', 'contents': {'type': 'bubble', 'direction': 'ltr', 'hero': {'type': 'image', 'url': 'https://sneakerdb103g3.serveo.net/material/product/33399_CSNT.jpg', 'size': 'full', 'aspectRatio': '1.51:1', 'aspectMode': 'fit'}, 'body': {'type': 'box', 'layout': 'vertical', 'contents': [{'type': 'text', 'text': 'skechers', 'align': 'center', 'weight': 'bold'}, {'type': 'text', 'text': "Women's BOBS Beach Bingo 2", 'align': 'center'}, {'type': 'box', 'layout': 'horizontal', 'contents': [{'type': 'button', 'action': {'type': 'postback', 'label': '加入購物車', 'text': "::我要:Women's BO", 'data': 'tag=cart&product=33399_CSNT&userid=999'}}, {'type': 'button', 'action': {'type': 'postback', 'label': '加入收藏', 'text': "Women's BO::加入收藏:", 'data': 'tag=collection&product=33399_CSNT&userid=999'}}]}, {'type': 'separator'}]}, 'footer': {'type': 'box', 'layout': 'horizontal', 'contents': [{'type': 'text', 'text': '評分', 'gravity': 'center'}, {'type': 'button', 'action': {'type': 'postback', 'label': '1', 'data': 'tag=Productsrecommend&rating=1&product=33399_CSNT&userid=999'}}, {'type': 'button', 'action': {'type': 'postback', 'label': '2', 'data': 'tag=Productsrecommend&rating=2&product=33399_CSNT&userid=999'}}, {'type': 'button', 'action': {'type': 'postback', 'label': '3', 'data': 'tag=Productsrecommend&rating=3&product=33399_CSNT&userid=999'}}, {'type': 'button', 'action': {'type': 'postback', 'label': '4', 'data': 'tag=Productsrecommend&rating=4&product=33399_CSNT&userid=999'}}, {'type': 'button', 'action': {'type': 'postback', 'label': '5', 'data': 'tag=Productsrecommend&rating=5&product=33399_CSNT&userid=999'}}]}}}
