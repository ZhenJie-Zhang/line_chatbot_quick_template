# %%
import mysql.connector

try:
    # 建立連線 並指定 database
    conn = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db', database='TEST1')
    cursor = conn.cursor()

    # 下 query指令 範例：只找 pid, pro_name, brand, url 的資料
    query = "SELECT pid, coler_label FROM shoes_data WHERE coler_label = 'brown'"
    cursor.execute(query)

    # 儲存讀取到的資料
    col_list = []
    for c in cursor:
        print(c)
    
    print('total', cursor.rowcount, 'shoes_data')
# 關閉連線
finally:
    cursor.close()
# Out:
# ('1016843419732553', 'brown')
# ('10375442618821452', 'brown')
# ('10375442619171503', 'brown')
# ('10375442619203235', 'brown')
# ('11294037977456988', 'brown')
# ('11813139151245051', 'brown')
# ('11813139151538534', 'brown')
# ('12837_MVE', 'brown')
# ('12891_ROS', 'brown')
# ('12938511207098717', 'brown')
# ('12938511207158743', 'brown')
# ('12938511207158744', 'brown')
# ('12938511207158745', 'brown')
# ('12946_ROS', 'brown')
# ('13067_LAV', 'brown')
# ('13076_ROS', 'brown')
# ('13128_LPD', 'brown')
# ('14097096494105391', 'brown')
# ('14097096494105392', 'brown')
# ('14097096494105393', 'brown')
# ('1473020371368274', 'brown')
# ('1473020371378565', 'brown')
# ('1473020371416770', 'brown')
# ('14881_RSGD', 'brown')
# ('15430_NAT', 'brown')
# ('15442_NAT', 'brown')
# ('16110_NAT', 'brown')
# ('16390_ROS', 'brown')
# ('16398_BRN', 'brown')
# ('16433_CSNT', 'brown')
# ('16635_CHOC', 'brown')
# ('18250_CSNT', 'brown')
# ('204056_CDB', 'brown')
# ('2307389542179546', 'brown')
# ('2307389542179825', 'brown')
# ('2307389542180663', 'brown')
# ('2307389542180858', 'brown')
# ('2307389542180861', 'brown')
# ('2307389542181452', 'brown')
# ('2307389542181587', 'brown')
# ('2307389542181740', 'brown')
# ('2307389542181869', 'brown')
# ('2307389542182005', 'brown')
# ('2307389542182017', 'brown')
# ('2307389542182356', 'brown')
# ('2307389542182463', 'brown')
# ('2307389542182493', 'brown')
# ('2307389542911250', 'brown')
# ('2307389542911254', 'brown')
# ('23638_TPE', 'brown')
# ('23763_TPE', 'brown')
# ('27052_RSGD', 'brown')
# ('3000029-201', 'brown')
# ('3020326-200', 'brown')
# ('3021587-103', 'brown')
# ('3021587-104', 'brown')
# ('3021589-104', 'brown')
# ('3021589-600', 'brown')
# ('3021966-800', 'brown')
# ('3022208-602', 'brown')
# ('3022209-200', 'brown')
# ('3022620-600', 'brown')
# ('3024088872826547', 'brown')
# ('3024088872839219', 'brown')
# ('3024088872839331', 'brown')
# ('3024088872856887', 'brown')
# ('3024088872927384', 'brown')
# ('31214_BRN', 'brown')
# ('314996-101', 'brown')
# ('31945_TAN', 'brown')
# ('31949_CSNT', 'brown')
# ('31963_MVE', 'brown')
# ('31963_ROS', 'brown')
# ('32553_NAT', 'brown')
# ('32575_LTPK', 'brown')
# ('32777_CSNT', 'brown')
# ('33267_CSNT', 'brown')
# ('333824-887', 'brown')
# ('33399_CSNT', 'brown')
# ('33444_ROS', 'brown')
# ('336416600172053', 'brown')
# ('33731_BRN', 'brown')
# ('34487_BRN', 'brown')
# ('3607804571908681', 'brown')
# ('3607804571908683', 'brown')
# ('3607804572053309', 'brown')
# ('3607804572092315', 'brown')
# ('3607804572252113', 'brown')
# ('3607804572252116', 'brown')
# ('3633577410768840', 'brown')
# ('3633577411364892', 'brown')
# ('3633577411364893', 'brown')
# ('3633577411817313', 'brown')
# ('3633577411817314', 'brown')
# ('3633577412068119', 'brown')
# ('3633577413460344', 'brown')
# ('3633577413623753', 'brown')
# ('3983529957846122', 'brown')
# ('3983529957846135', 'brown')
# ('3983529957846136', 'brown')
# ('3983529957918573', 'brown')
# ('3983529957977775', 'brown')
# ('3983529957977816', 'brown')
# ('3983529957977824', 'brown')
# ('3983529957977857', 'brown')
# ('3983529957977872', 'brown')
# ('3983529957977876', 'brown')
# ('3983529957977916', 'brown')
# ('3983529957977931', 'brown')
# ('3983529958022102', 'brown')
# ('3983529958022104', 'brown')
# ('3983529958257973', 'brown')
# ('3983529958286388', 'brown')
# ('3983529958286396', 'brown')
# ('3983529958722887', 'brown')
# ('3983529958723743', 'brown')
# ('3983529958724037', 'brown')
# ('3983529959371712', 'brown')
# ('3983529959609364', 'brown')
# ('3983529959620864', 'brown')
# ('3983529959633803', 'brown')
# ('3983529959633814', 'brown')
# ('3983529959633833', 'brown')
# ('3983529959633840', 'brown')
# ('3983529959633841', 'brown')
# ('3983529959633845', 'brown')
# ('3983529959633849', 'brown')
# ('3983529959633850', 'brown')
# ('3983529959645095', 'brown')
# ('3983529959645099', 'brown')
# ('3983529959645100', 'brown')
# ('3983529959648254', 'brown')
# ('3983529959672204', 'brown')
# ('3983529959672209', 'brown')
# ('3983529959676235', 'brown')
# ('3983529959676239', 'brown')
# ('3983529959676240', 'brown')
# ('3983529959676242', 'brown')
# ('3983529959676254', 'brown')
# ('3983529959676259', 'brown')
# ('3983529959676267', 'brown')
# ('3983529959676273', 'brown')
# ('3983529959676296', 'brown')
# ('3983529959676301', 'brown')
# ('3983529959676303', 'brown')
# ('3983529959720246', 'brown')
# ('3983529959720254', 'brown')
# ('3983529959720256', 'brown')
# ('4068790126374622', 'brown')
# ('4068790126661171', 'brown')
# ('4068790126684419', 'brown')
# ('4146401442995426', 'brown')
# ('4146401442999224', 'brown')
# ('4146401443075466', 'brown')
# ('4146401443885168', 'brown')
# ('4146401443885169', 'brown')
# ('4146401443885171', 'brown')
# ('4146401443943008', 'brown')
# ('4146401444107635', 'brown')
# ('4146401444198935', 'brown')
# ('4146401444198937', 'brown')
# ('4146401444198938', 'brown')
# ('4146401444198939', 'brown')
# ('4146401444198940', 'brown')
# ('4146401444198943', 'brown')
# ('4146401444198946', 'brown')
# ('4146401444198955', 'brown')
# ('4146401444198956', 'brown')
# ('4146401444235948', 'brown')
# ('4146401444285882', 'brown')
# ('4146401444285884', 'brown')
# ('4146401444287310', 'brown')
# ('432997-112', 'brown')
# ('44637_BURG', 'brown')
# ('44673_BLSH', 'brown')
# ('44703_DSCH', 'brown')
# ('49647_CSNT', 'brown')
# ('51502_BRN', 'brown')
# ('5179529849991960', 'brown')
# ('52464_CHOC', 'brown')
# ('52767_BURG', 'brown')
# ('5432698981522129', 'brown')
# ('5432698981522134', 'brown')
# ('5432698981522144', 'brown')
# ('547799495796784', 'brown')
# ('547799495796790', 'brown')
# ('547799495796791', 'brown')
# ('547799495796797', 'brown')
# ('547799495796799', 'brown')
# ('547799495804449', 'brown')
# ('5526882327949073', 'brown')
# ('5526882327952111', 'brown')
# ('5526882328139134', 'brown')
# ('5526882328147780', 'brown')
# ('5526882328147840', 'brown')
# ('55502_KHK', 'brown')
# ('5756269973089077', 'brown')
# ('5756269973089080', 'brown')
# ('5756269973089083', 'brown')
# ('5756269973089085', 'brown')
# ('5756269973089093', 'brown')
# ('5756269973089095', 'brown')
# ('5756269973089098', 'brown')
# ('5756269973089102', 'brown')
# ('5756269973089103', 'brown')
# ('5756269973089104', 'brown')
# ('5983760397828961', 'brown')
# ('5983760397828962', 'brown')
# ('5983760397828963', 'brown')
# ('5983760397828965', 'brown')
# ('5983760397861324', 'brown')
# ('5983760397928303', 'brown')
# ('5983760397928307', 'brown')
# ('5983760397928315', 'brown')
# ('5983760397984805', 'brown')
# ('5983760398324361', 'brown')
# ('5983760398330267', 'brown')
# ('5983760398330269', 'brown')
# ('5983760398354300', 'brown')
# ('5983760398354306', 'brown')
# ('61779_CDB', 'brown')
# ('62607_DSCH', 'brown')
# ('63697_CDB', 'brown')
# ('64224_CDB', 'brown')
# ('64260_BRN', 'brown')
# ('64260_CDB', 'brown')
# ('64440_DKBR', 'brown')
# ('64857_LUG', 'brown')
# ('64858_CDB', 'brown')
# ('64858_DSCH', 'brown')
# ('65981_TPE', 'brown')
# ('65984_CDB', 'brown')
# ('66073_CDB', 'brown')
# ('66082_CDB', 'brown')
# ('66146_CDB', 'brown')
# ('66153_CDB', 'brown')
# ('66177_BROL', 'brown')
# ('66199_BRN', 'brown')
# ('66229_CDB', 'brown')
# ('66230_CDB', 'brown')
# ('66232_CDB', 'brown')
# ('66237_CDB', 'brown')
# ('66240_CDB', 'brown')
# ('66297_CDB', 'brown')
# ('66299_DSCH', 'brown')
# ('66339_CDB', 'brown')
# ('66403_TAN', 'brown')
# ('66404_CDB', 'brown')
# ('66405_COG', 'brown')
# ('66416_CDB', 'brown')
# ('66417_CDB', 'brown')
# ('66431_COG', 'brown')
# ('666467151853165', 'brown')
# ('666467151853255', 'brown')
# ('666467151853265', 'brown')
# ('666467151982884', 'brown')
# ('666467151985205', 'brown')
# ('666467151985451', 'brown')
# ('666467151986984', 'brown')
# ('666467151987509', 'brown')
# ('666467151989157', 'brown')
# ('666467151992500', 'brown')
# ('666467151992787', 'brown')
# ('666467151993213', 'brown')
# ('666467151993586', 'brown')
# ('68304_CRML', 'brown')
# ('68309_CRML', 'brown')
# ('68311_CRML', 'brown')
# ('68312_CRML', 'brown')
# ('68313_DSRT', 'brown')
# ('68319_COG', 'brown')
# ('68604_NVY', 'brown')
# ('68699_COG', 'brown')
# ('68699_WINE', 'brown')
# ('68863_PNK', 'brown')
# ('68864_CSNT', 'brown')
# ('68961_BRN', 'brown')
# ('68998_TPE', 'brown')
# ('73690_ROS', 'brown')
# ('73762_LTPK', 'brown')
# ('74213_BKMT', 'brown')
# ('74335_BRN', 'brown')
# ('74335_LTBR', 'brown')
# ('76461509659712', 'brown')
# ('76461509921057', 'brown')
# ('777330-962', 'brown')
# ('864349-202', 'brown')
# ('921464-200', 'brown')
# ('922471-900', 'brown')
# ('924453-604', 'brown')
# ('AC7104', 'brown')
# ('AH1016-602', 'brown')
# ('AJ6877-700', 'brown')
# ('AJ7200-006', 'brown')
# ('AJ7200-202', 'brown')
# ('AO0352-203', 'brown')
# ('AO2445-900', 'brown')
# ('AO3116-200', 'brown')
# ('AO3189-600', 'brown')
# ('AO4550-603', 'brown')
# ('AO7507-200', 'brown')
# ('AQ0104', 'brown')
# ('AQ0114-200', 'brown')
# ('AQ0114-600', 'brown')
# ('AQ1180', 'brown')
# ('AQ1202-900', 'brown')
# ('AQ2567-200', 'brown')
# ('AQ3744-900', 'brown')
# ('AQ3774-992', 'brown')
# ('AQ3778-992', 'brown')
# ('AQ7460-201', 'brown')
# ('AQ7492-603', 'brown')
# ('AR5339-603', 'brown')
# ('AR5339-800', 'brown')
# ('AR6632-603', 'brown')
# ('AR8835-600', 'brown')
# ('AR9293-602', 'brown')
# ('AR9293-603', 'brown')
# ('AT3146-204', 'brown')
# ('AT3147-600', 'brown')
# ('AT8242-600', 'brown')
# ('AV3610-779', 'brown')
# ('AV6259-800', 'brown')
# ('AV9376-602', 'brown')
# ('B37920', 'brown')
# ('B43526', 'brown')
# ('B43663', 'brown')
# ('BD7626', 'brown')
# ('BD8002', 'brown')
# ('BQ1918-102', 'brown')
# ('BQ1918-400', 'brown')
# ('BQ4223-700', 'brown')
# ('BQ4326-700', 'brown')
# ('BQ5468-601', 'brown')
# ('BQ5616-200', 'brown')
# ('BQ5888-200', 'brown')
# ('BQ5888-300', 'brown')
# ('BQ6623-800', 'brown')
# ('BQ6840-200', 'brown')
# ('BV0074-200', 'brown')
# ('BV0417-600', 'brown')
# ('BV1654-200', 'brown')
# ('CD8526-866', 'brown')
# ('CG5130', 'brown')
# ('CG5989', 'brown')
# ('CG6060', 'brown')
# ('CI0603-600', 'brown')
# ('CI0811-808', 'brown')
# ('CI2082-800', 'brown')
# ('CI9907-100', 'brown')
# ('CJ7698-106', 'brown')
# ('CJ9178-200', 'brown')
# ('CJ9179-200', 'brown')
# ('CK0834-200', 'brown')
# ('CK0835-200', 'brown')
# ('CK4851-800', 'brown')
# ('EE4109', 'brown')
# ('EE4561', 'brown')
# ('EE4722', 'brown')
# ('EE5411', 'brown')
# ('EE5441', 'brown')
# ('EE5507', 'brown')
# ('EE5541', 'brown')
# ('EE5543', 'brown')
# ('EE5566', 'brown')
# ('EE5613', 'brown')
# ('EE5908', 'brown')
# ('EE5915', 'brown')
# ('EE6044', 'brown')
# ('EE6145', 'brown')
# ('EE6245', 'brown')
# ('EE6358', 'brown')
# ('EE6434', 'brown')
# ('EE6435', 'brown')
# ('EE6462', 'brown')
# ('EE6465', 'brown')
# ('EE7017', 'brown')
# ('EE8090', 'brown')
# ('EE8272', 'brown')
# ('EE8377', 'brown')
# ('EE8521', 'brown')
# ('EE8629', 'brown')
# ('EE9574', 'brown')
# ('EF0444', 'brown')
# ('EF0475', 'brown')
# ('EF1155', 'brown')
# ('EF2044', 'brown')
# ('EF9317', 'brown')
# ('EG2937', 'brown')
# ('EG6649', 'brown')
# ('EG7728', 'brown')
# ('F33593', 'brown')
# ('F34054', 'brown')
# ('F34087', 'brown')
# ('F34484', 'brown')
# ('F35129', 'brown')
# ('F35567', 'brown')
# ('F35767', 'brown')
# ('F36259', 'brown')
# ('G25870', 'brown')
# ('G26161', 'brown')
# ('G26457', 'brown')
# ('G26458', 'brown')
# ('G26605', 'brown')
# ('G26821', 'brown')
# ('G27482', 'brown')
# ('G27515', 'brown')
# ('G27709', 'brown')
# ('G27736', 'brown')
# ('G27891', 'brown')
# ('G28060', 'brown')
# ('G28242', 'brown')
# ('G28264', 'brown')
# ('G28278', 'brown')
# ('G28331', 'brown')
# ('G28426', 'brown')
# ('G54013', 'brown')
# ('G54017', 'brown')
# ('G54640', 'brown')
# ('G54642', 'brown')
# ('H839N-2121', 'brown')
# ('MD1100DB', 'brown')
# ('MD1200SB', 'brown')
# ('WSRMCKP', 'brown')
# ('WXNRGSC', 'brown')
# total 425 shoes_data

# %%
import mysql.connector
import json

secretFileContentJson=json.load(open("./line_secret_key",'r'))
server_url=secretFileContentJson.get("server_url")

cursor = None
conn = None
l = 'white'
try:
    # 建立連線 並指定 database
    conn = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db', database='TEST1')
    cursor = conn.cursor()
    
    # 下 query指令 範例：只找 mcolor_label = 2 的資料
    query = "SELECT pid, pro_name, brand FROM shoes_data WHERE coler_label = "+repr(l)+" && mcolor_name like '%"+l+"%' ORDER BY RAND(), mcolor_pa desc LIMIT 5"
    print(query)
    cursor.execute(query)
    
    # 顯示讀取到的資料
#     for pid, mcolor_label, scolor_label, mcolor_id in cursor:
#         print('pid={}, m_label={}, s_label={}, mc_id={}'.format(pid, mcolor_label, scolor_label, mcolor_id))
    col_list = []
    for pid, pro_name, brand in cursor:
        pic_url = 'https://'+server_url+'/material/product/'+pid+'.jpg'
        print(pid, pro_name, brand, pic_url)
        #循環加到 list_col_color
        col = {
                "thumbnailImageUrl": pic_url,
                "title": pro_name,
                "text": "所顏是否?",
                "actions": [
                  {
                    "type": "postback",
                    "label": "喜歡",
                    "text": "加入喜好清單",
                    "data": "tag=maincolor|Secondarycolor|"+pid
                  },
                  {
                    "type": "postback",
                    "label": "不喜歡",
                    "text": "不喜歡"+pro_name,
                    "data": "tag=maincolor|Secondarycolor|"+pid
                  }
                ]
              }
        col_list.append(col)

    #輸出到linebot輪播
    data = [
        {
            "type": "template",
            "altText": "情境輸入推薦清單",
            "template":{
                    "type": "carousel",
                    "actions": [],
                    "columns": col_list
            }
        }
    ]
    print(json.dumps(data, indent=2,ensure_ascii=False))


    print('total', cursor.rowcount, 'shoes_data')
# 關閉連線
finally:
    cursor.close()

# %%
import mysql.connector
import json

userid = '999'

try:
    # 建立連線 並指定 database
    conn = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db', database='TEST1')
    cursor = conn.cursor()
    
    # 下 query指令 範例：只找 mcolor_label = 2 的資料
    query = "SELECT pid, pro_name, brand FROM shoes_data WHERE coler_label = "+repr(l)+" && mcolor_name like '%"+l+"%' ORDER BY RAND(), mcolor_pa desc LIMIT 5"
    print(query)
    cursor.execute(query)
    
    # 顯示讀取到的資料
#     for pid, mcolor_label, scolor_label, mcolor_id in cursor:
#         print('pid={}, m_label={}, s_label={}, mc_id={}'.format(pid, mcolor_label, scolor_label, mcolor_id))
    contentsList = []
    for pid, pro_name, brand in cursor:
        pic_url = 'https://'+server_url+'/material/product/'+pid+'.jpg'
        print(pid, pro_name, brand, pic_url)
        #循環加到 list_col_color

        bubbleDict = {
                "type": "bubble",
                "direction": "ltr",
                "hero": {
                  "type": "image",
                  "url": pic_url,
                  "size": "full",
                  "aspectRatio": "1.51:1",
                  "aspectMode": "fit"
                },
                "body": {
                  "type": "box",
                  "layout": "vertical",
                  "contents": [
                    {
                      "type": "text",
                      "text": pro_name[:40],
                      "align": "center"
                    },
                    {
                      "type": "box",
                      "layout": "horizontal",
                      "contents": [
                        {
                          "type": "button",
                          "action": {
                            "type": "postback",
                            "label": "加入購物車",
                            "text": "我要"+pro_name[:10],
                            "data": "product="+pid+"&user="+userid
                          }
                        },
                        {
                          "type": "button",
                          "action": {
                            "type": "postback",
                            "label": "加入收藏",
                            "data": "product="+pid+"&user="+userid
                          }
                        }
                      ]
                    },
                    {
                      "type": "separator"
                    }
                  ]
                },
                "footer": {
                  "type": "box",
                  "layout": "horizontal",
                  "contents": [
                    {
                      "type": "text",
                      "text": "喜好",
                      "gravity": "center"
                    },
                    {
                      "type": "button",
                      "action": {
                        "type": "postback",
                        "label": "1",
                        "data": "rating=1&product="+pid+"&user="+userid
                      }
                    },
                    {
                      "type": "button",
                      "action": {
                        "type": "postback",
                        "label": "2",
                        "data": "rating=2&product="+pid+"&user="+userid
                      }
                    },
                    {
                      "type": "button",
                      "action": {
                        "type": "postback",
                        "label": "3",
                        "data": "rating=3&product="+pid+"&user="+userid
                      }
                    },
                    {
                      "type": "button",
                      "action": {
                        "type": "postback",
                        "label": "4",
                        "data": "rating=4&product="+pid+"&user="+userid
                      }
                    },
                    {
                      "type": "button",
                      "action": {
                        "type": "postback",
                        "label": "5",
                        "data": "rating=5&product="+pid+"&user="+userid
                      }
                    }
                  ]
                }
              }

        contentsList.append(bubbleDict)
    Flex_Message = [{
      "type": "flex",
      "altText": "Flex Message",
      "contents": {
        "type": "carousel",
        "contents": contentsList
      }
    }]
# 關閉連線
finally:
    cursor.close()
    print(json.dumps(Flex_Message, indent=2,ensure_ascii=False))

# %% [markdown]
# # 建立shoes_rating表格至MySQL

# %%
import mysql.connector

db = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db')

cursor = db.cursor()

# 新建 database
cursor.execute("DROP DATABASE IF EXISTS user")
cursor.execute("CREATE DATABASE IF not EXISTS user")

# 顯示目前所有的database
cursor.execute("SHOW DATABASES")

for x in cursor:
    print(x)

# %%
import pandas as pd
from sqlalchemy import create_engine
df1 = pd.read_csv('/root/linechatbot/recommend/ratings.csv', encoding='utf-8')

#csv 匯入 DB
engine = create_engine('mysql+pymysql://root:123456@chatbot_db/user?charset=utf8')

with engine.connect() as conn, conn.begin():
    df1.to_sql('shoes_rating', conn, if_exists='replace', index=True)

df1

#build connenction
import pymysql
connection = pymysql.connect(host='chatbot_db', 
                             user='root',
                             password='123456',
                             charset='utf8mb4',
                             database='TEST1',
                             cursorclass=pymysql.cursors.DictCursor)

with connection.cursor() as cursor:
    sql = "USE `user`"
    cursor.execute(sql)
    sql_query = "SELECT * FROM `shoes_rating`"
    cursor.execute(sql_query)
    result = cursor.fetchone()
    print(result)

# %%
import mysql.connector

cursor = None
conn = None
try:
    # 建立連線 並指定 database
    conn = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db', database='user')
    cursor = conn.cursor()
    
    # 下 query指令 範例：只找 mcolor_label = 2 的資料
    query = "SELECT count(*) FROM `shoes_rating`"
#     query = "SELECT pid, mcolor_label, scolor_label FROM shoes_data"
#     query = "SELECT * FROM shoes_data"
    cursor.execute(query)
    
    # 顯示讀取到的資料
#     for pid, mcolor_label, scolor_label, mcolor_id in cursor:
#         print('pid={}, m_label={}, s_label={}, mc_id={}'.format(pid, mcolor_label, scolor_label, mcolor_id))
    for c in cursor:
        print(c)
        
    print('total', cursor.rowcount, 'shoes_data')
# 關閉連線
finally:
    cursor.close()

# %% [markdown]
# # 建立shoes表格至MySQL

# %%
import mysql.connector

db = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db')

cursor = db.cursor()

# 新建 database
# cursor.execute("DROP DATABASE IF EXISTS user")
# cursor.execute("CREATE DATABASE IF not EXISTS user")

# 顯示目前所有的database
cursor.execute("SHOW DATABASES")

for x in cursor:
    print(x)

# %%
import mysql.connector

db = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db')

cursor = db.cursor()

# 新建 database
cursor.execute("USE `TEST1`")
# cursor.execute("DROP TABLE IF EXISTS shoes")
# cursor.execute("CREATE DATABASE IF not EXISTS user")

# 顯示目前所有的database
cursor.execute("SHOW TABLES")

for x in cursor:
    print(x)

# %%
import mysql.connector

db = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db')

cursor = db.cursor()

# 新建 database
cursor.execute("USE `user`")
# cursor.execute("DROP TABLE IF EXISTS shoes")
# cursor.execute("CREATE DATABASE IF not EXISTS user")

# 顯示目前所有的database
cursor.execute("SHOW TABLES")

for x in cursor:
    print(x)

# %%
import pandas as pd
from sqlalchemy import create_engine
df1 = pd.read_csv('/root/linechatbot/recommend/shoes_20191107.csv', encoding='utf-8-sig')

#csv 匯入 DB
engine = create_engine('mysql+pymysql://root:123456@chatbot_db/user?charset=utf8')

with engine.connect() as conn, conn.begin():
    df1.to_sql('shoes', conn, if_exists='replace', index=True)

df1

# %%
#build connenction
import pymysql
connection = pymysql.connect(host='chatbot_db', 
                             user='root',
                             password='123456',
                             charset='utf8mb4',
                             database='TEST1',
                             cursorclass=pymysql.cursors.DictCursor)

with connection.cursor() as cursor:
    sql = "USE `user`"
    cursor.execute(sql)
    sql_query = "SELECT * FROM `shoes`"
    cursor.execute(sql_query)
    result = cursor.fetchone()
    print(result)

# %%
import mysql.connector

cursor = None
conn = None
try:
    # 建立連線 並指定 database
    conn = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db', database='TEST1')
    cursor = conn.cursor()
    
    # 下 query指令 範例：只找 mcolor_label = 2 的資料
    query = "SELECT * FROM `shoes_data` limit 1"
    cursor.execute(query)
    
    # 顯示讀取到的資料
#     for shoesIDX,shoesID in cursor:
#         print(shoesIDX,shoesID)
    for c in cursor:
        print(c[0])
        
    print('total', cursor.rowcount, 'shoes')
# 關閉連線
finally:
    cursor.close()
# Out:
# 0
# total 1 shoes

# %%
import mysql.connector

cursor = None
conn = None
try:
    # 建立連線 並指定 database
    conn = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db', database='user')
    cursor = conn.cursor()
    
    # 下 query指令 範例：只找 mcolor_label = 2 的資料
    query = "SELECT shoesIDX, shoesID FROM `shoes` where shoesID = 'WZANSCS'"
    cursor.execute(query)
    
    # 顯示讀取到的資料
    for shoesIDX,shoesID in cursor:
        print(shoesIDX,shoesID)
#     for c in cursor:
#         print(c[0])
        
    print('total', cursor.rowcount, 'shoes')
# 關閉連線
finally:
    cursor.close()

# %%
#Creating, Reading, Updating and Deleting Records
import redis

conn3 = redis.StrictRedis(
    host='redis',
    port="6379",
    password='123456',
    ssl=False, charset="utf-8", decode_responses=True)
shoes_list = conn3.hgetall("shoes")
shoes_list

# %%
#Creating, Reading, Updating and Deleting Records
import redis

conn3 = redis.StrictRedis(
    host='redis',
    port="6379",
    password='123456',
    ssl=False, charset="utf-8", decode_responses=True)
shoes_list = conn3.hget("shoes", 611)
shoes_list

# %%
#Creating, Reading, Updating and Deleting Records
import redis
import mysql.connector

conn3 = redis.StrictRedis(
    host='redis',
    port="6379",
    password='123456',
    ssl=False, charset="utf-8", decode_responses=True)
shoes_list = eval(conn3.hget("shoes", 611))
for i, s in enumerate(shoes_list):
#     print(i+1, s)
    
    cursor = None
    conn = None
    try:
        # 建立連線 並指定 database
        conn = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db', database='user')
        cursor = conn.cursor()

        # 下 query指令 範例：只找 mcolor_label = 2 的資料
        query = "SELECT shoesIDX, shoesID FROM `shoes` where shoesID = "+repr(s[0])
        cursor.execute(query)

        # 顯示讀取到的資料
        for shoesIDX,shoesID in cursor:
            print(shoesIDX,shoesID)

    # 關閉連線
    finally:
        cursor.close()
        print("-----")

# %%
#Creating, Reading, Updating and Deleting Records
import redis
import mysql.connector

conn3 = redis.StrictRedis(
    host='redis',
    port="6379",
    password='123456',
    ssl=False, charset="utf-8", decode_responses=True)
shoes_list = eval(conn3.hget("shoes", 611))
for i, s in enumerate(shoes_list):
    if i > 5:
        break
    pid = s[0]
    print(pid)
    cursor = None
    conn = None
    try:
        # 建立連線 並指定 database
        conn = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db', database='TEST1')
        cursor = conn.cursor()

        # 下 query指令 範例：只找 mcolor_label = 2 的資料
        query = "SELECT pid, pro_name, brand FROM `shoes_data` where pid ="+repr(pid)
        cursor.execute(query)

        # 顯示讀取到的資料
#         for shoesIDX,shoesID in cursor:
#             print(shoesIDX,shoesID)
        for c in cursor:
            print(c)

    # 關閉連線
    finally:
        cursor.close()
        print("-----")

# %%
import redis

def getRecommendList(userid):
    conn3 = redis.StrictRedis(
        host='redis',
        port="6379",
        password='123456',
        ssl=False, charset="utf-8", decode_responses=True)
    shoes_list = eval(conn3.hget("shoes", userid))
    
    recommendIDlist = []
    for pid, _, _ in shoes_list:
        recommendIDlist.append(pid)
    
    return recommendIDlist

getRecommendList(611)
# Out:
# ['AC8229',
#  'CI9871-100',
#  '232001_CCBK',
#  'B96285',
#  'BV1654-100',
#  'BY3301',
#  '3983529959633803',
#  '1011A541-021',
#  '1011A019-300',
#  '5983760398354309',
#  '68981_BKW',
#  '31949_CSNT',
#  '66100_CDB',
#  '1012A026-400',
#  '1021A056-021',
#  '16701_BBK',
#  'CJ0949-100',
#  '1011A550-800',
#  '31214_BLK',
#  '78904_BBK',
#  '54410_BKW',
#  'AO7351-002',
#  '1011A242-700',
#  '15600_CHAR',
#  '1012A002-001']

# %%
import mysql.connector

def getRecommendDataList(RecommendIDList, num=5):
    RecommendDataList = []
    for i, s in enumerate(RecommendIDList):
        if i > num:
            break
        pid = s
        cursor = None
        conn = None
        try:
            # 建立連線 並指定 database
            conn = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db', database='TEST1')
            cursor = conn.cursor()

            # 下 query指令 範例：只找 mcolor_label = 2 的資料
            query = "SELECT pid, pro_name, brand FROM `shoes_data` where pid ="+repr(pid)
            cursor.execute(query)
            
            for c in cursor:
                RecommendDataList.append(c)

        # 關閉連線
        finally:
            cursor.close()
    return RecommendDataList

RecommendIDList = getRecommendList(611)
RecommendDataList = getRecommendDataList(RecommendIDList)
RecommendDataList
# Out:
# [('AC8229',
#   'adidas Adizero 5-Star 7.0 Lax Mid Cleats - Black | adidas US',
#   'adidas'),
#  ('CI9871-100', 'Nike Air Max 97', 'nike'),
#  ('232001_CCBK', "Men's Track - Knockhill", 'skechers'),
#  ('B96285', 'adidas SolarBoost Shoes - Blue | adidas US', 'adidas'),
#  ('BV1654-100', 'Jordan Proto-React', 'nike'),
#  ('BY3301', 'adidas Icon Trainer Shoes - White | adidas US', 'adidas')]

# %%
from linebot import (
    LineBotApi, WebhookHandler
)

import json

# 載入基礎設定檔
secretFileContentJson=json.load(open("./line_secret_key",'r'))
server_url=secretFileContentJson.get("server_url")

# 生成實體物件
line_bot_api = LineBotApi(secretFileContentJson.get("channel_access_token"))


# 找出使用者推薦清單的輪播訊訊息陣列

def findRecommend(userid):
    # 取出消息內User的資料
#     user_profile = line_bot_api.get_profile(userid)
    # 取得user的推薦清單
    RecommendIDList = getRecommendList(userid)
    RecommendDataList = getRecommendDataList(RecommendIDList)
    
    
    # 準備放入輪播清單的list
    contentsList = []
    for pid, pro_name, brand in RecommendDataList:
        pic_url = 'https://'+server_url+'/material/product/'+pid+'.jpg'
        print(pid, pro_name, brand, pic_url)
        #循環加到 list_col_color

        bubbleDict = {
                "type": "bubble",
                "direction": "ltr",
                "hero": {
                  "type": "image",
                  "url": pic_url,
                  "size": "full",
                  "aspectRatio": "1.51:1",
                  "aspectMode": "fit"
                },
                "body": {
                  "type": "box",
                  "layout": "vertical",
                  "contents": [
                    {
                      "type": "text",
                      "text": brand,
                      "align": "center",
                      "weight": "bold"
                    },
                    {
                      "type": "text",
                      "text": pro_name[:40],
                      "align": "center"
                    },
                    {
                      "type": "box",
                      "layout": "horizontal",
                      "contents": [
                        {
                          "type": "button",
                          "action": {
                            "type": "postback",
                            "label": "加入購物車",
                            "text": "我想買"+pro_name[:10],
                            "data": "tag=cart&product="+pid+"&userid="+str(userid)
                          }
                        },
                        {
                          "type": "button",
                          "action": {
                            "type": "postback",
                            "label": "加入收藏",
                            "text": pro_name[:10]+"加入收藏",
                            "data": "tag=collection&product="+pid+"&userid="+str(userid)
                          }
                        }
                      ]
                    },
                    {
                      "type": "separator"
                    }
                  ]
                },
                "footer": {
                  "type": "box",
                  "layout": "horizontal",
                  "contents": [
                    {
                      "type": "text",
                      "text": "評分",
                      "gravity": "center"
                    },
                    {
                      "type": "button",
                      "action": {
                        "type": "postback",
                        "label": "1",
                        "data": "rating=1&product="+pid+"&userid="+str(userid)
                      }
                    },
                    {
                      "type": "button",
                      "action": {
                        "type": "postback",
                        "label": "2",
                        "data": "rating=2&product="+pid+"&userid="+str(userid)
                      }
                    },
                    {
                      "type": "button",
                      "action": {
                        "type": "postback",
                        "label": "3",
                        "data": "rating=3&product="+pid+"&userid="+str(userid)
                      }
                    },
                    {
                      "type": "button",
                      "action": {
                        "type": "postback",
                        "label": "4",
                        "data": "rating=4&product="+pid+"&userid="+str(userid)
                      }
                    },
                    {
                      "type": "button",
                      "action": {
                        "type": "postback",
                        "label": "5",
                        "data": "rating=5&product="+pid+"&userid="+str(userid)
                      }
                    }
                  ]
                }
              }

        contentsList.append(bubbleDict)
    Flex_Message = [
        {
          "type": "text",
          "text": "您好\n以下是根據您看過的商品，你可能喜歡以下商品"+u"\U0001f600"+"\n"
        },
        {
          "type": "flex",
          "altText": "商品推薦",
          "contents": {
            "type": "carousel",
            "contents": contentsList
          }
        }]
#     result_message_array = detect_json_array_to_linebot_message_array(Flex_Message)
    return Flex_Message

findRecommend(611)

# %%
import mysql.connector
import json

secretFileContentJson=json.load(open("./line_secret_key",'r'))
server_url=secretFileContentJson.get("server_url")

userid = '999'

try:
    # 建立連線 並指定 database
    conn = mysql.connector.connect(user='root', password='123456', host = 'chatbot_db', database='TEST1')
    cursor = conn.cursor()
    
    # 下 query指令 範例：只找 mcolor_label = 2 的資料
    query = "SELECT pid, pro_name, brand FROM shoes_data ORDER BY RAND() LIMIT 1"
    print(query)
    cursor.execute(query)
    
    # 顯示讀取到的資料
#     for pid, mcolor_label, scolor_label, mcolor_id in cursor:
#         print('pid={}, m_label={}, s_label={}, mc_id={}'.format(pid, mcolor_label, scolor_label, mcolor_id))
    contentsList = []
    for pid, pro_name, brand in cursor:
        pic_url = 'https://'+server_url+'/material/product/'+pid+'.jpg'
        print(pid, pro_name, brand, pic_url)
        #循環加到 list_col_color
        flextemplate = {
                      "type": "flex",
                      "altText": "Flex Message",
                      "contents": {
                        "type": "bubble",
                        "direction": "ltr",
                        "hero": {
                          "type": "image",
                          "url": pic_url,
                          "size": "full",
                          "aspectRatio": "1.51:1",
                          "aspectMode": "fit"
                        },
                        "body": {
                          "type": "box",
                          "layout": "vertical",
                          "contents": [
                            {
                              "type": "text",
                              "text": brand,
                              "align": "center",
                              "weight": "bold"
                            },
                            {
                              "type": "text",
                              "text": pro_name,
                              "align": "center"
                            },
                            {
                              "type": "box",
                              "layout": "horizontal",
                              "contents": [
                                {
                                  "type": "button",
                                  "action": {
                                    "type": "postback",
                                    "label": "加入購物車",
                                    "text": "::我要:"+pro_name[:10],
                                    "data": "tag=cart&product="+pid+"&userid="+userid
                                  }
                                },
                                {
                                  "type": "button",
                                  "action": {
                                    "type": "postback",
                                    "label": "加入收藏",
                                    "text": pro_name[:10]+"::加入收藏:",
                                    "data": "tag=collection&product="+pid+"&userid="+userid
                                  }
                                }
                              ]
                            },
                            {
                              "type": "separator"
                            }
                          ]
                        },
                        "footer": {
                          "type": "box",
                          "layout": "horizontal",
                          "contents": [
                            {
                              "type": "text",
                              "text": "評分",
                              "gravity": "center"
                            },
                            {
                              "type": "button",
                              "action": {
                                "type": "postback",
                                "label": "1",
                                "data": "tag=Productsrecommend&rating=1&product="+pid+"&userid="+userid
                              }
                            },
                            {
                              "type": "button",
                              "action": {
                                "type": "postback",
                                "label": "2",
                                "data": "tag=Productsrecommend&rating=2&product="+pid+"&userid="+userid
                              }
                            },
                            {
                              "type": "button",
                              "action": {
                                "type": "postback",
                                "label": "3",
                                "data": "tag=Productsrecommend&rating=3&product="+pid+"&userid="+userid
                              }
                            },
                            {
                              "type": "button",
                              "action": {
                                "type": "postback",
                                "label": "4",
                                "data": "tag=Productsrecommend&rating=4&product="+pid+"&userid="+userid
                              }
                            },
                            {
                              "type": "button",
                              "action": {
                                "type": "postback",
                                "label": "5",
                                "data": "tag=Productsrecommend&rating=5&product="+pid+"&userid="+userid
                              }
                            }
                          ]
                        }
                      }
                    }
    print(flextemplate)
            
# 關閉連線
finally:
    cursor.close()
#     print(json.dumps(Flex_Message, indent=2,ensure_ascii=False))
